# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('unicorns.csv')
# data.set_index('Company')
# Out:
#                         Updated at  \
# Company
# Esusu       10/31/2022, 2:37:05 AM
# Fever Labs  10/31/2022, 2:37:05 AM
# Minio       10/31/2022, 2:37:04 AM
# Darwinbox   10/31/2022, 2:37:04 AM
# Pentera     10/31/2022, 2:37:04 AM
# ...                            ...
# Fanatics    10/31/2022, 2:32:42 AM
# SpaceX      10/31/2022, 2:32:38 AM
# Vice Media  10/31/2022, 2:33:10 AM
# Klarna      10/31/2022, 2:33:05 AM
# Veepee      10/31/2022, 2:35:27 AM
#
#                                                Crunchbase Url  \
# Company
# Esusu                https://www.cbinsights.com/company/esusu
# Fever Labs      https://www.cbinsights.com/company/fever-labs
# Minio                https://www.cbinsights.com/company/minio
# Darwinbox        https://www.cbinsights.com/company/darwinbox
# Pentera             https://www.cbinsights.com/company/pcysys
# ...                                                       ...
# Fanatics          https://www.cbinsights.com/company/fanatics
# SpaceX      https://www.cbinsights.com/company/space-explo...
# Vice Media      https://www.cbinsights.com/company/vice-media
# Klarna              https://www.cbinsights.com/company/klarna
# Veepee        https://www.cbinsights.com/company/vente-privee
#
#             Last Valuation (Billion $) Date Joined  Year Joined  \
# Company
# Esusu                             1.00   1/27/2022         2022
# Fever Labs                        1.00   1/26/2022         2022
# Minio                             1.00   1/26/2022         2022
# Darwinbox                         1.00   1/25/2022         2022
# Pentera                           1.00   1/11/2022         2022
# ...                                ...         ...          ...
# Fanatics                         27.00    6/6/2012         2012
# SpaceX                          127.00   12/1/2012         2012
# Vice Media                        5.70    4/2/2011         2011
# Klarna                            6.70  12/12/2011         2011
# Veepee                            1.38    7/2/2007         2007
#
#                              City        Country  \
# Company
# Esusu                    New York  United States
# Fever Labs               New York  United States
# Minio                   Palo Alto  United States
# Darwinbox               Hyderabad          India
# Pentera               Petah Tikva         Israel
# ...                           ...            ...
# Fanatics             Jacksonville  United States
# SpaceX                  Hawthorne  United States
# Vice Media               Brooklyn  United States
# Klarna                  Stockholm         Sweden
# Veepee      La Plaine Saint-Denis         France
#
#                                    Industry  \
# Company
# Esusu                               Fintech
# Fever Labs     Internet software & services
# Minio           Data management & analytics
# Darwinbox      Internet software & services
# Pentera                      Cybersecurity
# ...                                     ...
# Fanatics    E-commerce & direct-to-consumer
# SpaceX                                Other
# Vice Media     Internet software & services
# Klarna                              Fintech
# Veepee      E-commerce & direct-to-consumer
#
#                                                     Investors  Company Website
# Company
# Esusu       ["Next Play Ventures","Zeal Capital Partners",...              NaN
# Fever Labs                        ["Accel","14W","GS Growth"]              NaN
# Minio       ["General Catalyst","Nexus Venture Partners","...              NaN
# Darwinbox   ["Lightspeed India Partners","Sequoia Capital ...              NaN
# Pentera      ["AWZ Ventures","Blackstone","Insight Partners"]              NaN
# ...                                                       ...              ...
# Fanatics    ["SoftBank Group","Andreessen Horowitz","Temas...              NaN
# SpaceX      ["Founders Fund","Draper Fisher Jurvetson","Ro...              NaN
# Vice Media  ["Technology Crossover Ventures","A&E Televisi...              NaN
# Klarna      ["Institutional Venture Partners","Sequoia Cap...              NaN
# Veepee                    ["Summit Partners","Qatar Holding"]              NaN
#
# [1199 rows x 10 columns]

# %%
data.groupby('Country').Country.count()
# Out:
# Country
# Argentina                 1
# Australia                 8
# Austria                   2
# Bahamas                   1
# Belgium                   3
# Bermuda                   1
# Brazil                   16
# Canada                   19
# Chile                     2
# China                   173
# Colombia                  3
# Croatia                   2
# Czech Republic            1
# Denmark                   2
# Ecuador                   1
# Estonia                   2
# Finland                   4
# France                   24
# Germany                  29
# Hong Kong                 7
# India                    70
# Indonesia                 7
# Ireland                   6
# Israel                   23
# Italy                     2
# Japan                     6
# Liechtenstein             1
# Lithuania                 2
# Luxembourg                1
# Malaysia                  1
# Mexico                    8
# Netherlands               7
# Nigeria                   1
# Norway                    5
# Philippines               2
# Senegal                   1
# Seychelles                1
# Singapore                14
# South Africa              2
# South Korea              16
# Spain                     5
# Sweden                    8
# Switzerland               6
# Thailand                  3
# Turkey                    3
# United Arab Emirates      3
# United Kingdom           47
# United States           645
# Vietnam                   2
# Name: Country, dtype: int64

# %%
data.groupby('Country').Valuation.agg([min,max,len]).plot(kind='bar',figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Country'>

# %%
data
# Out:
#                   Updated at     Company  \
# 0     10/31/2022, 2:37:05 AM       Esusu
# 1     10/31/2022, 2:37:05 AM  Fever Labs
# 2     10/31/2022, 2:37:04 AM       Minio
# 3     10/31/2022, 2:37:04 AM   Darwinbox
# 4     10/31/2022, 2:37:04 AM     Pentera
# ...                      ...         ...
# 1194  10/31/2022, 2:32:42 AM    Fanatics
# 1195  10/31/2022, 2:32:38 AM      SpaceX
# 1196  10/31/2022, 2:33:10 AM  Vice Media
# 1197  10/31/2022, 2:33:05 AM      Klarna
# 1198  10/31/2022, 2:35:27 AM      Veepee
#
#                                          Crunchbase Url  Valuation  \
# 0              https://www.cbinsights.com/company/esusu       1.00
# 1         https://www.cbinsights.com/company/fever-labs       1.00
# 2              https://www.cbinsights.com/company/minio       1.00
# 3          https://www.cbinsights.com/company/darwinbox       1.00
# 4             https://www.cbinsights.com/company/pcysys       1.00
# ...                                                 ...        ...
# 1194        https://www.cbinsights.com/company/fanatics      27.00
# 1195  https://www.cbinsights.com/company/space-explo...     127.00
# 1196      https://www.cbinsights.com/company/vice-media       5.70
# 1197          https://www.cbinsights.com/company/klarna       6.70
# 1198    https://www.cbinsights.com/company/vente-privee       1.38
#
#      Date Joined  Year Joined                   City        Country  \
# 0      1/27/2022         2022               New York  United States
# 1      1/26/2022         2022               New York  United States
# 2      1/26/2022         2022              Palo Alto  United States
# 3      1/25/2022         2022              Hyderabad          India
# 4      1/11/2022         2022            Petah Tikva         Israel
# ...          ...          ...                    ...            ...
# 1194    6/6/2012         2012           Jacksonville  United States
# 1195   12/1/2012         2012              Hawthorne  United States
# 1196    4/2/2011         2011               Brooklyn  United States
# 1197  12/12/2011         2011              Stockholm         Sweden
# 1198    7/2/2007         2007  La Plaine Saint-Denis         France
#
#                              Industry  \
# 0                             Fintech
# 1        Internet software & services
# 2         Data management & analytics
# 3        Internet software & services
# 4                      Cybersecurity
# ...                               ...
# 1194  E-commerce & direct-to-consumer
# 1195                            Other
# 1196     Internet software & services
# 1197                          Fintech
# 1198  E-commerce & direct-to-consumer
#
#                                               Investors  Company Website
# 0     ["Next Play Ventures","Zeal Capital Partners",...              NaN
# 1                           ["Accel","14W","GS Growth"]              NaN
# 2     ["General Catalyst","Nexus Venture Partners","...              NaN
# 3     ["Lightspeed India Partners","Sequoia Capital ...              NaN
# 4      ["AWZ Ventures","Blackstone","Insight Partners"]              NaN
# ...                                                 ...              ...
# 1194  ["SoftBank Group","Andreessen Horowitz","Temas...              NaN
# 1195  ["Founders Fund","Draper Fisher Jurvetson","Ro...              NaN
# 1196  ["Technology Crossover Ventures","A&E Televisi...              NaN
# 1197  ["Institutional Venture Partners","Sequoia Cap...              NaN
# 1198                ["Summit Partners","Qatar Holding"]              NaN
#
# [1199 rows x 11 columns]

# %%
data.groupby(['Industry','Country']).Valuation.agg([min,max,len])
# Out:
#                                        min   max  len
# Industry                Country
# Artificial Intelligence China          1.0  1.46    4
#                         United States  1.0  2.50    7
# Artificial intelligence Bermuda        1.6  1.60    1
#                         Brazil         2.6  2.60    1
#                         Canada         1.0  1.20    2
# ...                                    ...   ...  ...
# Travel                  Indonesia      3.0  3.00    1
#                         South Korea    1.0  1.00    1
#                         Spain          1.3  1.30    1
#                         Sweden         1.0  1.00    1
#                         United States  9.2  9.20    1
#
# [216 rows x 3 columns]

# %%
data.groupby(['Country','City']).Valuation.count()
# Out:
# Country        City
# Argentina      Buenos Aires        1
# Australia      Alexandria          1
#                Brisbane            1
#                Melbourne           2
#                Richmond            1
#                                   ..
# United States  Washington DC       2
#                Westerville         1
#                Wilmington          2
#                Zephyr Cove         1
# Vietnam        Ho Chi Minh City    2
# Name: Valuation, Length: 285, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1199 entries, 0 to 1198
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Updated at                  1199 non-null   object
#  1   Company                     1199 non-null   object
#  2   Crunchbase Url              1199 non-null   object
#  3   Last Valuation (Billion $)  1199 non-null   float64
#  4   Date Joined                 1199 non-null   object
#  5   Year Joined                 1199 non-null   int64
#  6   City                        1181 non-null   object
#  7   Country                     1199 non-null   object
#  8   Industry                    1199 non-null   object
#  9   Investors                   1199 non-null   object
#  10  Company Website             0 non-null      float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 103.2+ KB

# %%
data.head(5)
# Out:
#                Updated at     Company  \
# 0  10/31/2022, 2:37:05 AM       Esusu
# 1  10/31/2022, 2:37:05 AM  Fever Labs
# 2  10/31/2022, 2:37:04 AM       Minio
# 3  10/31/2022, 2:37:04 AM   Darwinbox
# 4  10/31/2022, 2:37:04 AM     Pentera
#
#                                   Crunchbase Url  Last Valuation (Billion $)  \
# 0       https://www.cbinsights.com/company/esusu                         1.0
# 1  https://www.cbinsights.com/company/fever-labs                         1.0
# 2       https://www.cbinsights.com/company/minio                         1.0
# 3   https://www.cbinsights.com/company/darwinbox                         1.0
# 4      https://www.cbinsights.com/company/pcysys                         1.0
#
#   Date Joined  Year Joined         City        Country  \
# 0   1/27/2022         2022     New York  United States
# 1   1/26/2022         2022     New York  United States
# 2   1/26/2022         2022    Palo Alto  United States
# 3   1/25/2022         2022    Hyderabad          India
# 4   1/11/2022         2022  Petah Tikva         Israel
#
#                        Industry  \
# 0                       Fintech
# 1  Internet software & services
# 2   Data management & analytics
# 3  Internet software & services
# 4                Cybersecurity
#
#                                            Investors  Company Website
# 0  ["Next Play Ventures","Zeal Capital Partners",...              NaN
# 1                        ["Accel","14W","GS Growth"]              NaN
# 2  ["General Catalyst","Nexus Venture Partners","...              NaN
# 3  ["Lightspeed India Partners","Sequoia Capital ...              NaN
# 4   ["AWZ Ventures","Blackstone","Insight Partners"]              NaN

# %% [markdown]
# # 1.1 determine how many industries are represented in the data and how much each

# %%
# print(data['Industry'].value_counts())
data['Industry'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # determine which nation has the most fintech-based startups.

# %%
fintech_df=data.loc[data.Industry== 'Fintech']
fintech_df['Country'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
Internet_software_services_df=data.loc[data.Industry== 'Internet software & services']
Internet_software_services_df['Country'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# As can be seen, Fintech has the highest number of startups, followed by internet software companies.

# %% [markdown]
# # 1.2 Let's see which year has the most startups established And which are they

# %%
data['Year Joined'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
Compony_22=data.loc[data['Year Joined'] == 2022]
Compony_22['Company']
# Out:
# 0                   Esusu
# 1              Fever Labs
# 2                   Minio
# 3               Darwinbox
# 4                 Pentera
#               ...
# 242                 Qonto
# 243    The Boring Company
# 244                 RELEX
# 245                KuCoin
# 246                  Miro
# Name: Company, Length: 247, dtype: object

# %%
comp_2022_fintech=data.loc[(data.Industry =='Fintech') & (data['Year Joined']==2022)]
comp_2022_fintech['Country'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# As can be seen, the United States will have the most established Fintech Startups by 2022.

# %%
comp_2022_Internet=data.loc[(data.Industry =='Internet software & services') & (data['Year Joined']==2022)]
comp_2022_Internet['Country'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data.groupby(['Country',])

# %%
# data['Investors'].value_counts()
data.loc[(data.Country == 'India') & (data.Investors) ]
# Out:
#                   Updated at      Company  \
# 3     10/31/2022, 2:37:04 AM    Darwinbox
# 13    10/31/2022, 2:37:15 AM  LeadSquared
# 23    10/31/2022, 2:37:13 AM         Open
# 41    10/31/2022, 2:37:09 AM        Amagi
# 50    10/31/2022, 2:37:07 AM       Hasura
# ...                      ...          ...
# 1067  10/31/2022, 2:32:51 AM       Swiggy
# 1120  10/31/2022, 2:32:43 AM       BYJU's
# 1177  10/31/2022, 2:36:14 AM       InMobi
# 1179  10/31/2022, 2:36:13 AM     Snapdeal
# 1186  10/31/2022, 2:33:06 AM     Ola Cabs
#
#                                          Crunchbase Url  Valuation  \
# 3          https://www.cbinsights.com/company/darwinbox        1.0
# 13       https://www.cbinsights.com/company/leadsquared        1.0
# 23              https://www.cbinsights.com/company/open        1.0
# 41    https://www.cbinsights.com/company/amagi-media...        1.0
# 50            https://www.cbinsights.com/company/hasura        1.0
# ...                                                 ...        ...
# 1067          https://www.cbinsights.com/company/swiggy       10.7
# 1120           https://www.cbinsights.com/company/byjus       22.0
# 1177          https://www.cbinsights.com/company/inmobi        1.0
# 1179        https://www.cbinsights.com/company/snapdeal        1.0
# 1186  https://www.cbinsights.com/company/ani-technol...        7.5
#
#      Date Joined  Year Joined       City Country  \
# 3      1/25/2022         2022  Hyderabad   India
# 13     6/21/2022         2022  Bengaluru   India
# 23      5/2/2022         2022  Bengaluru   India
# 41     3/16/2022         2022  Bengaluru   India
# 50     2/22/2022         2022  Bengaluru   India
# ...          ...          ...        ...     ...
# 1067   6/21/2018         2018  Bengaluru   India
# 1120   7/25/2017         2017  Bengaluru   India
# 1177   12/2/2014         2014  Bengaluru   India
# 1179   5/21/2014         2014  New Delhi   India
# 1186  10/27/2014         2014  Bengaluru   India
#
#                                  Industry  \
# 3            Internet software & services
# 13           Internet software & services
# 23                                Fintech
# 41           Internet software & services
# 50           Internet software & services
# ...                                   ...
# 1067  Supply chain, logistics, & delivery
# 1120                               Edtech
# 1177          Mobile & telecommunications
# 1179      E-commerce & direct-to-consumer
# 1186                Auto & transportation
#
#                                               Investors  Company Website
# 3     ["Lightspeed India Partners","Sequoia Capital ...              NaN
# 13    ["Gaja Capital Partners","Stakeboat Capital","...              NaN
# 23    ["3one4 Capital Partners","Tiger Global Manage...              NaN
# 41      ["Mayfield","Accel","Norwest Venture Partners"]              NaN
# 50    ["Nexus Venture Partners","Vertex Ventures","S...              NaN
# ...                                                 ...              ...
# 1067  ["Accel India","SAIF Partners","Norwest Ventur...              NaN
# 1120  ["Tencent Holdings","Lightspeed India Partners...              NaN
# 1177  ["Kleiner Perkins Caufield & Byers","Softbank ...              NaN
# 1179      ["SoftBankGroup","Blackrock","Alibaba Group"]              NaN
# 1186  ["Accel Partners","SoftBank Group","Sequoia Ca...              NaN
#
# [70 rows x 11 columns]

# %%
data.groupby('Company').Valuation.max()
# Out:
# Company
# 0x                  1.05
# 1047 Games          1.50
# 1KMXC               1.00
# 1Password           6.80
# 21.co               2.00
#                    ...
# reddit             10.00
# solarisBank         1.65
# stori               1.20
# thatgamecompany     1.94
# wefox               4.50
# Name: Valuation, Length: 1196, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1199 entries, 0 to 1198
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Updated at       1199 non-null   object
#  1   Company          1199 non-null   object
#  2   Crunchbase Url   1199 non-null   object
#  3   Valuation        1199 non-null   float64
#  4   Date Joined      1199 non-null   object
#  5   Year Joined      1199 non-null   int64
#  6   City             1181 non-null   object
#  7   Country          1199 non-null   object
#  8   Industry         1199 non-null   object
#  9   Investors        1199 non-null   object
#  10  Company Website  0 non-null      float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 103.2+ KB

# %% [markdown]
# # Is there a particular geographical region that is driving the growth of Fintech startups or internet software companies?

# %%
country_indus_Val=data.groupby(['Country','Industry']).Valuation.count()

# %%
country_indus_Val=pd.DataFrame(country_indus_Val)

# %%
country_indus_Val
# Out:
#                                                    Valuation
# Country       Industry
# Argentina     Fintech                                      1
# Australia     E-commerce & direct-to-consumer              1
#               Fintech                                      2
#               Internet software & services                 5
# Austria       Edtech                                       1
# ...                                                      ...
# United States Other                                       33
#               Supply chain, logistics, & delivery         26
#               Travel                                       1
# Vietnam       Fintech                                      1
#               Internet software & services                 1
#
# [216 rows x 1 columns]

# %% [markdown]
# # Let's now determine which industries India has.

# %%
# renaming the column
data = data.rename(columns={'Last Valuation (Billion $)': 'Valuation'})

# %%
data_ind=data.loc[data.Country.isin(['India'])]
data_ind.Industry.value_counts().plot(kind='bar')
data_ind['Industry'].value_counts()
# Out:
# Fintech                                17
# E-commerce & direct-to-consumer        17
# Internet software & services           13
# Edtech                                  7
# Supply chain, logistics, & delivery     7
# Other                                   2
# Health                                  2
# Auto & transportation                   2
# Data management & analytics             1
# Travel                                  1
# Mobile & telecommunications             1
# Name: Industry, dtype: int64

# %% [markdown]
# # Which startups in India are more valuable, and what are they?

# %%
ind_sorted_df=data_ind.sort_values("Valuation", ascending=False)
sns.set_theme(style="whitegrid")
f, ax = plt.subplots(figsize=(6, 15))
sns.set_color_codes("pastel")
sns.barplot(x="Valuation", y="Company", data=ind_sorted_df,
            label="Valuation", color="g")
sns.despine(left=True, bottom=True)

# %% [markdown]
# # Let's take a look at where each fintech startup is located in India.

# %%
fin_df=data.loc[data['Industry'] == 'Fintech']
ind_fin_df=fin_df.loc[fin_df.Country.isin(['India'])]
# ind_fin_df['Company'].value_counts()
ind_fin_df.groupby('Company').Valuation.max().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Company'>

# %%
data[]

# %%
ind_sorted_df=data_ind.sort_values("Valuation", ascending=False)
sns.set_theme(style="whitegrid")
f, ax = plt.subplots(figsize=(6, 15))
sns.set_color_codes("pastel")
sns.barplot(x="Valuation", y="Company", data=ind_sorted_df,
            label="Valuation", color="g")
sns.despine(left=True, bottom=True)

# %% [markdown]
# # Continue

# %%
data_ind=data.loc[data.Country.isin(['China'])]
data_ind.Industry.value_counts().plot(kind='bar')
data_ind['Industry'].value_counts()
# Out:
# E-commerce & direct-to-consumer        28
# Hardware                               18
# Auto & transportation                  18
# Internet software & services           15
# Artificial intelligence                15
# Mobile & telecommunications            13
# Supply chain, logistics, & delivery    12
# Edtech                                 12
# Health                                 10
# Consumer & retail                       8
# Fintech                                 8
# Other                                   6
# Artificial Intelligence                 4
# Travel                                  3
# Data management & analytics             2
# Cybersecurity                           1
# Name: Industry, dtype: int64

# %%
data.loc[data.]

# %%
def plot_industry(inds,state):
    fin_df=data.loc[data['Industry'] == inds]
    ind_fin_df=fin_df.loc[fin_df.Country.isin([state])]
    ind_fin_df=ind_fin_df.sort_values(by='Valuation',ascending=True)
    ind_fin_df.groupby('Company').Valuation.max().plot(kind='bar')
    
    
plot_industry('Fintech','India')

# %%
ind_fin_df=ind_fin_df.sort_values(by=['Valuation'],ascending=True)
ind_fin_df
# Out:
#                  Updated at                           Company  \
# 23   10/31/2022, 2:37:13 AM                              Open
# 292  10/31/2022, 2:36:53 AM                          MobiKwik
# 405  10/31/2022, 2:36:02 AM            Acko General Insurance
# 126  10/31/2022, 2:35:35 AM                        CredAvenue
# 143  10/31/2022, 2:35:25 AM                           OneCard
# 558  10/31/2022, 2:34:45 AM                             Slice
# 563  10/31/2022, 2:34:42 AM                  CoinSwitch Kuber
# 608  10/31/2022, 2:34:21 AM                           CoinDCX
# 931  10/31/2022, 2:34:11 AM                      PolicyBazaar
# 657  10/31/2022, 2:33:57 AM                          BharatPe
# 664  10/31/2022, 2:33:54 AM                             Groww
# 691  10/31/2022, 2:33:42 AM                            Upstox
# 712  10/31/2022, 2:33:33 AM                   Digit Insurance
# 721  10/31/2022, 2:33:28 AM                              CRED
# 854  10/31/2022, 2:33:17 AM                         Pine Labs
# 864  10/31/2022, 2:33:06 AM  National Stock Exchange of India
# 868  10/31/2022, 2:33:02 AM                          Razorpay
#
#                                         Crunchbase Url  Valuation Date Joined  \
# 23             https://www.cbinsights.com/company/open       1.00    5/2/2022
# 292        https://www.cbinsights.com/company/mobikwik       1.00  10/13/2021
# 405  https://www.cbinsights.com/company/acko-genera...       1.10  10/28/2021
# 126      https://www.cbinsights.com/company/credavenue       1.30    3/7/2022
# 143    https://www.cbinsights.com/company/onescore-app       1.40   7/13/2022
# 558           https://www.cbinsights.com/company/slice       1.80  11/28/2021
# 563      https://www.cbinsights.com/company/coinswitch       1.90   10/6/2021
# 608         https://www.cbinsights.com/company/coindcx       2.15   8/10/2021
# 931    https://www.cbinsights.com/company/policybazaar       2.40    5/6/2019
# 657        https://www.cbinsights.com/company/bharatpe       2.85   7/30/2021
# 664           https://www.cbinsights.com/company/groww       3.00    4/7/2021
# 691            https://www.cbinsights.com/company/rksv       3.40  11/29/2021
# 712  https://www.cbinsights.com/company/digit-insur...       4.00   1/15/2021
# 721            https://www.cbinsights.com/company/cred       4.01    4/6/2021
# 854       https://www.cbinsights.com/company/pine-labs       5.00   1/24/2020
# 864  https://www.cbinsights.com/company/national-st...       6.50    7/1/2020
# 868  https://www.cbinsights.com/company/razorpay-so...       7.50  10/11/2020
#
#      Year Joined         City Country Industry  \
# 23          2022    Bengaluru   India  Fintech
# 292         2021     Gurugram   India  Fintech
# 405         2021    Bengaluru   India  Fintech
# 126         2022      Chennai   India  Fintech
# 143         2022         Pune   India  Fintech
# 558         2021    Bengaluru   India  Fintech
# 563         2021    Bangalore   India  Fintech
# 608         2021  Maharashtra   India  Fintech
# 931         2019      Gurgaon   India  Fintech
# 657         2021    New Delhi   India  Fintech
# 664         2021    Bengaluru   India  Fintech
# 691         2021       Mumbai   India  Fintech
# 712         2021    Bengaluru   India  Fintech
# 721         2021    Bengaluru   India  Fintech
# 854         2020        Noida   India  Fintech
# 864         2020       Mumbai   India  Fintech
# 868         2020    Bengaluru   India  Fintech
#
#                                              Investors  Company Website
# 23   ["3one4 Capital Partners","Tiger Global Manage...              NaN
# 292  ["Sequoia Capital India","The Times Group","GM...              NaN
# 405  ["Intact Ventures","Munich Re Ventures","Gener...              NaN
# 126  ["Insight Partners","B Capital Group","\tLight...              NaN
# 143  ["Sequoia Capital India","Hummingbird Ventures...              NaN
# 558  ["Gunosy Capital","Blume Ventures","Das Capital"]              NaN
# 563  ["Tiger Global Management","Sequoia Capital In...              NaN
# 608  ["Polychain Capital","Coinbase Ventures","Jump...              NaN
# 931                   ["Info Edge","Softbank Capital"]              NaN
# 657  ["Insight Partners","Sequoia Capital India","B...              NaN
# 664  ["Tiger Global Management","Sequoia Capital In...              NaN
# 691      ["Tiger Global Management","Kalaari Capital"]              NaN
# 712  ["Fairfax Financial Holdings","A91 Partners","...              NaN
# 721  ["Tiger Global Management","DST Global","Sequo...              NaN
# 854  ["Sequoia Capital India","Temasek","PayPal Ven...              NaN
# 864     ["TA Associates","SoftBank Group","GS Growth"]              NaN
# 868  ["Sequoia Capital India","Tiger Global Managem...              NaN
